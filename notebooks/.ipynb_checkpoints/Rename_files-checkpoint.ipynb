# %%
import os
from copy import copy

raw_data_folder = "/media/ceolin/Data/Lab Gompel/Projects/Fly_Abdomens/data/01_raw/multiple"

os.chdir(raw_data_folder)
#os.rename('a.txt', 'b.kml')

for file in os.listdir():
    if file.endswith(".tif"):
        old_name = copy(file)
        if "C=0" in old_name:
            new_name = "C1-"+old_name.replace(".lif - ","_").replace(" - C=0","")
        if "C=1" in old_name:
            new_name = "C2-"+old_name.replace(".lif - ","_").replace(" - C=1","")
        print(old_name)
        
20190126 - Experiment_A0B0_male1.tif
# Out:
# 20190222 - Experiment.lif - A0B0_male_1 - C=1.tif
# 20190126 - Experiment.lif - 3B01_female1 - C=0.tif
# 20190126 - Experiment.lif - 3B01_female1 - C=1.tif
# 20190126 - Experiment.lif - 3B01_male1 - C=0.tif
# 20190126 - Experiment.lif - 3B01_male1 - C=1.tif
# 20190126 - Experiment.lif - 3B01_male2 - C=0.tif
# 20190126 - Experiment.lif - 3B01_male2 - C=1.tif
# 20190126 - Experiment.lif - 3B01_male3 - C=0.tif
# 20190126 - Experiment.lif - 3B01_male3 - C=1.tif
# 20190126 - Experiment.lif - A0B0_female1 - C=0.tif
# 20190126 - Experiment.lif - A0B0_female1 - C=1.tif
# 20190126 - Experiment.lif - A0B0_male1 - C=1.tif
# 20190126 - Experiment.lif - A0B0_male2 - C=0.tif
# 20190126 - Experiment.lif - A0B0_male2 - C=1.tif
# 20190126 - Experiment.lif - A3B0_female1 - C=0.tif
# 20190126 - Experiment.lif - A3B0_female1 - C=1.tif
# 20190127 - Experiment.lif - A2B0_female1 - C=0.tif
# 20190127 - Experiment.lif - A2B0_female1 - C=1.tif
# 20190127 - Experiment.lif - A2B0_femlae2 - C=0.tif
# ...
